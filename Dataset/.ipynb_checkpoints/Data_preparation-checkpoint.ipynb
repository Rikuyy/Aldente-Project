# %%
#CookCash

# %%
import pandas as pd
import numpy as np
from pymongo import MongoClient
from sklearn.model_selection import train_test_split
import re # Library wajib buat manipulasi teks/kata

df = pd.read_csv('Book5.csv', sep=';')

print("Data mentah berhasil dimuat! Ukuran awal:", df.shape)
display(df.head(3))
# Out:
# Data mentah berhasil dimuat! Ukuran awal: (11595, 10)
#                       Title  \
# 0          Ayam Woku Manado
# 1  Ayam goreng tulang lunak
# 2          Ayam cabai kawin
#
#                                          Ingredients  \
# 0  1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk ...
# 1  1 kg ayam (dipotong sesuai selera jangan kecil...
# 2  1/4 kg ayam--3 buah cabai hijau besar--7 buah ...
#
#                                                Steps  Loves  \
# 0  1) Cuci bersih ayam dan tiriskan. Lalu peras j...      1
# 1  1) Haluskan bumbu2nya (BaPut, ketumbar, kemiri...      1
# 2  1) Panaskan minyak di dalam wajan. Setelah min...      2
#
#                                                  URL Category  \
# 0  https://cookpad.com/id/resep/4473027-ayam-woku...     ayam
# 1  https://cookpad.com/id/resep/4471956-ayam-gore...     ayam
# 2  https://cookpad.com/id/resep/4473057-ayam-caba...     ayam
#
#               Title Cleaned  Total Ingredients  \
# 0          ayam woku manado                 14
# 1  ayam goreng tulang lunak                 11
# 2          ayam cabai kawin                 10
#
#                                  Ingredients Cleaned  Total Steps
# 0  ayam kampung potong , jeruk nipis , garam , ku...            7
# 1  ayam dipotong , serai , daun jeruk , bawang pu...            5
# 2  ayam , cabai hijau , cabai merah rawit , bawan...            3

# %%
print("--- 1. DATA UNDERSTANDING ---")
print("\nInfo Kolom dan Tipe Data:")
df.info()

print("\nCek Data Kosong (Missing Values):")
print(df.isnull().sum())

print("\nCek Data Duplikat:")
print("Jumlah duplikat:", df.duplicated().sum())
# Out:
# --- 1. DATA UNDERSTANDING ---
#
# Info Kolom dan Tipe Data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11595 entries, 0 to 11594
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                11595 non-null  object
#  1   Ingredients          11595 non-null  object
#  2   Steps                11595 non-null  object
#  3   Loves                11595 non-null  int64
#  4   URL                  11595 non-null  object
#  5   Category             11595 non-null  object
#  6   Title Cleaned        11594 non-null  object
#  7   Total Ingredients    11595 non-null  int64
#  8   Ingredients Cleaned  11595 non-null  object
#  9   Total Steps          11595 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 906.0+ KB
#
# Cek Data Kosong (Missing Values):
# Title                  0
# Ingredients            0
# Steps                  0
# Loves                  0
# URL                    0
# Category               0
# Title Cleaned          1
# Total Ingredients      0
# Ingredients Cleaned    0
# Total Steps            0
# dtype: int64
#
# Cek Data Duplikat:
# Jumlah duplikat: 0

# %%
print("--- 2. DATA CLEANING ---")

# 1. Hapus kolom yang tidak diperlukan 
df.drop(columns=['URL', 'Title', 'Ingredients'], inplace=True, errors='ignore')

# 2. Tentukan kolom penting (pakai yang cleaned)
kolom_wajib = ['Title Cleaned', 'Ingredients Cleaned', 'Steps', 'Category']

# 2.5: Membersihkan kata-kata "noise" di Judul Resep
# Tambahkan kata-kata lain yang sekiranya mau kamu buang ke dalam list ini
kata_buang = ['simpel', 'simple', 'menu diet', 'ala', 'rumahan', 'mudah', 'enak', 'endes','akuhhh hihihi','endeuss','bunda','umy','kadarnya',
              'praktis', 'gampang', 'super', 'spesial', 'special', 'mantap', 'endues','niceketo','hemat gas','dijamin jogja banget',
              'ovi','yamiiii', 'sederhana','setan','yummy','bu quro v','atha','no msg','rimara','menu balita','no msg no pengembang no pengenyal',
              'kriuk','masakan','anti ribet','vey','mamais','ph','murah meriah','dee','alalala','valen','endess','slowakia',
              'resep kilat','yah','hehe','irit','ekonomis','without pho','nikmat','by erni hartanti amd','suka','simpel','nampol','anti gagal']

# Bikin pola regex biar dia nyari kata-kata di atas secara otomatis
pola = r'\b(?:' + '|'.join(kata_buang) + r')\b'

# Eksekusi pembersihan di kolom Title Cleaned (Abaikan huruf besar/kecil)
df['Title Cleaned'] = df['Title Cleaned'].str.replace(pola, '', flags=re.IGNORECASE, regex=True)

# Rapikan spasi yang dobel gara-gara ada kata yang dihapus
df['Title Cleaned'] = df['Title Cleaned'].str.replace(r'\s+', ' ', regex=True).str.strip()
print("Kata-kata 'noise' berhasil dibersihkan dari judul!")
# =========================================================================

# 3. Cek missing values sebelum cleaning
print("\nMissing values sebelum cleaning:")
print(df[kolom_wajib].isnull().sum())

print("\nJumlah data sebelum:", df.shape)

# 4. Hapus baris yang punya nilai kosong
df.dropna(subset=kolom_wajib, inplace=True)

# 5. Cek duplikat sebelum dihapus
print("\nJumlah duplikat sebelum:", df.duplicated().sum())

# 6. Hapus duplikat
df.drop_duplicates(inplace=True)

# 7. Cek setelah cleaning
print("\nMissing values setelah cleaning:")
print(df[kolom_wajib].isnull().sum())

print("\nJumlah duplikat setelah:", df.duplicated().sum())
print("Jumlah data setelah:", df.shape)

# 8. Info akhir
print("\nProses Data Cleaning Selesai!")
print("Kolom tersedia:", df.columns.tolist())

display(df[['Title Cleaned']].head())
# Out:
# --- 2. DATA CLEANING ---
# Kata-kata 'noise' berhasil dibersihkan dari judul!
#
# Missing values sebelum cleaning:
# Title Cleaned          1
# Ingredients Cleaned    0
# Steps                  0
# Category               0
# dtype: int64
#
# Jumlah data sebelum: (11595, 7)
#
# Jumlah duplikat sebelum: 0
#
# Missing values setelah cleaning:
# Title Cleaned          0
# Ingredients Cleaned    0
# Steps                  0
# Category               0
# dtype: int64
#
# Jumlah duplikat setelah: 0
# Jumlah data setelah: (11594, 7)
#
# Proses Data Cleaning Selesai!
# Kolom tersedia: ['Steps', 'Loves', 'Category', 'Title Cleaned', 'Total Ingredients', 'Ingredients Cleaned', 'Total Steps']
#               Title Cleaned
# 0          ayam woku manado
# 1  ayam goreng tulang lunak
# 2          ayam cabai kawin
# 3               ayam geprek
# 4               minyak ayam

# %%
print("--- 5. DATA TRANSFORMATION ---")

# 1. Pastikan kolom numerik jadi Integer (Biar Chatbot bisa ngitung)
df['Loves'] = pd.to_numeric(df['Loves'], errors='coerce').fillna(0).astype(int)
df['Total Ingredients'] = pd.to_numeric(df['Total Ingredients'], errors='coerce').fillna(0).astype(int)
df['Total Steps'] = pd.to_numeric(df['Total Steps'], errors='coerce').fillna(0).astype(int)

# 2. Pastikan kolom teks jadi String
kolom_teks = ['Title Cleaned', 'Ingredients Cleaned', 'Steps', 'Category']

for col in kolom_teks:
    if col in df.columns: # Cek dulu biar gak error kalau kolomnya gak ada
        df[col] = df[col].astype(str)
        
# 3. REORDER: Susun ulang urutan kolom untuk mempermudah pembacaan
urutan_kolom = [
    'Title Cleaned', 
    'Ingredients Cleaned', 
    'Steps', 
    'Loves', 
    'Category', 
    'Total Ingredients', 
    'Total Steps'
]
df = df[urutan_kolom]

print("Transformasi Tipe Data & Reorder Kolom Selesai!")
display(df.head(2))
display(df.dtypes)
# Out:
# --- 5. DATA TRANSFORMATION ---
# Transformasi Tipe Data & Reorder Kolom Selesai!
#               Title Cleaned  \
# 0          ayam woku manado
# 1  ayam goreng tulang lunak
#
#                                  Ingredients Cleaned  \
# 0  ayam kampung potong , jeruk nipis , garam , ku...
# 1  ayam dipotong , serai , daun jeruk , bawang pu...
#
#                                                Steps  Loves Category  \
# 0  1) Cuci bersih ayam dan tiriskan. Lalu peras j...      1     ayam
# 1  1) Haluskan bumbu2nya (BaPut, ketumbar, kemiri...      1     ayam
#
#    Total Ingredients  Total Steps
# 0                 14            7
# 1                 11            5
# Title Cleaned          object
# Ingredients Cleaned    object
# Steps                  object
# Loves                   int64
# Category               object
# Total Ingredients       int64
# Total Steps             int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split

print("--- 6. DATA SPLITTING ---")

# Membagi data: 80% Train (Masuk DB), 20% Test (Buat Ujian AI)
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)

print(f" Data berhasil dibagi!")
print(f"   - Data Train: {len(df_train)} baris (Akan dikirim ke MongoDB)")
print(f"   - Data Test : {len(df_test)} baris (Disimpan sebagai file backup)")

# Simpan Data Test ke CSV buat nanti tahap evaluasi algoritma
df_test.to_csv('Cookcash_Data_Test.csv', index=False)
print(" File 'Cookcash_Data_Test.csv' berhasil dibuat.")
# Out:
# --- 6. DATA SPLITTING ---
#  Data berhasil dibagi!
#    - Data Train: 9275 baris (Akan dikirim ke MongoDB)
#    - Data Test : 2319 baris (Disimpan sebagai file backup)
#  File 'Cookcash_Data_Test.csv' berhasil dibuat.

# %%
import pymongo
from pymongo import MongoClient

print("--- 7. EXPORT TO MONGODB ---")

try:
    # 1. Koneksi ke MongoDB Lokal
    client = MongoClient('mongodb://localhost:27017/')
    db = client['cookcash_db'] # Nama Database kamu
    collection = db['resep']   # Nama Koleksi (Laci) resep kamu

    # 2. Kosongkan data lama (supaya tidak duplikat kalau di-run ulang)
    collection.delete_many({})

    # 3. Ubah df_train ke format dictionary yang dipahami MongoDB
    data_dict = df_train.to_dict(orient='records')

    # 4. Masukkan data
    collection.insert_many(data_dict)
    
    print(f" SUKSES! {len(data_dict)} data resep sukses masuk ke MongoDB.")
    print("Silakan cek di MongoDB Compass pada database 'cookcash_db'.")

except Exception as e:
    print(f" Koneksi Gagal! Pastikan MongoDB Compass / Service sudah jalan.")
    print(f"Error: {e}")
# Out:
# --- 7. EXPORT TO MONGODB ---
#  SUKSES! 9275 data resep sukses masuk ke MongoDB.
# Silakan cek di MongoDB Compass pada database 'cookcash_db'.
